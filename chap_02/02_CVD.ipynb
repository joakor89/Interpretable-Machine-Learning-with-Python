# %% [markdown]
# # Cardiovascular Disease Risk Factors

# %% [markdown]
# ### Loading Libraries

# %%
# Numerical Computing
import math
import numpy as np

# Data Manipulation
import pandas as pd

# Stats Model
import statsmodels.api as sm

# Scikit-Learn
from sklearn.model_selection import train_test_split

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datasets

# %%
# For Debian/Ubuntu-based systems, you can install it using the following command:
# !apt-get update && apt-get install -y libgl1-mesa-glx

# After installing the library, retry importing the module.
import machine_learning_datasets as mldatasets
# Out:
# Hit:1 http://deb.debian.org/debian bullseye InRelease
# Hit:2 http://deb.debian.org/debian-security bullseye-security InRelease
# Hit:3 http://deb.debian.org/debian bullseye-updates InRelease
#
#
#
#
# libgl1-mesa-glx is already the newest version (20.3.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %% [markdown]
# ### Understanding & Preparing Data

# %%
cvd_df = mldatasets.load("cardiovascular-disease")
# Out:
# https://raw.githubusercontent.com/caravanuden/cardio/master/cardio_train.csv downloaded to /datasets/_deepnote_work/data/cardio_train.csv
# 1 dataset files found in /datasets/_deepnote_work/data folder
# parsing /datasets/_deepnote_work/data/cardio_train.csv

# %%
cvd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 6.4 MB

# %% [markdown]
# ### Data Preparation

# %%
cvd_df['age'] =  cvd_df['age'] / 365.24

# %%
# def set_header_font():
#     return [dict(selector="th", props=[("font-size", "14pt")])]

# %%
def set_header_font():
    return [dict(selector="th", props=[("font-size", "14pt")])]


cvd_df.describe(percentiles=[.01,.99]).transpose().style.format('{:.2f}').\
                set_properties(**{'font-size': '16pt'}).set_table_styles(set_header_font())
# Out:
# <style type="text/css">
# #T_a7e44 th {
#   font-size: 14pt;
# }
# #T_a7e44_row0_col0, #T_a7e44_row0_col1, #T_a7e44_row0_col2, #T_a7e44_row0_col3, #T_a7e44_row0_col4, #T_a7e44_row0_col5, #T_a7e44_row0_col6, #T_a7e44_row0_col7, #T_a7e44_row1_col0, #T_a7e44_row1_col1, #T_a7e44_row1_col2, #T_a7e44_row1_col3, #T_a7e44_row1_col4, #T_a7e44_row1_col5, #T_a7e44_row1_col6, #T_a7e44_row1_col7, #T_a7e44_row2_col0, #T_a7e44_row2_col1, #T_a7e44_row2_col2, #T_a7e44_row2_col3, #T_a7e44_row2_col4, #T_a7e44_row2_col5, #T_a7e44_row2_col6, #T_a7e44_row2_col7, #T_a7e44_row3_col0, #T_a7e44_row3_col1, #T_a7e44_row3_col2, #T_a7e44_row3_col3, #T_a7e44_row3_col4, #T_a7e44_row3_col5, #T_a7e44_row3_col6, #T_a7e44_row3_col7, #T_a7e44_row4_col0, #T_a7e44_row4_col1, #T_a7e44_row4_col2, #T_a7e44_row4_col3, #T_a7e44_row4_col4, #T_a7e44_row4_col5, #T_a7e44_row4_col6, #T_a7e44_row4_col7, #T_a7e44_row5_col0, #T_a7e44_row5_col1, #T_a7e44_row5_col2, #T_a7e44_row5_col3, #T_a7e44_row5_col4, #T_a7e44_row5_col5, #T_a7e44_row5_col6, #T_a7e44_row5_col7, #T_a7e44_row6_col0, #T_a7e44_row6_col1, #T_a7e44_row6_col2, #T_a7e44_row6_col3, #T_a7e44_row6_col4, #T_a7e44_row6_col5, #T_a7e44_row6_col6, #T_a7e44_row6_col7, #T_a7e44_row7_col0, #T_a7e44_row7_col1, #T_a7e44_row7_col2, #T_a7e44_row7_col3, #T_a7e44_row7_col4, #T_a7e44_row7_col5, #T_a7e44_row7_col6, #T_a7e44_row7_col7, #T_a7e44_row8_col0, #T_a7e44_row8_col1, #T_a7e44_row8_col2, #T_a7e44_row8_col3, #T_a7e44_row8_col4, #T_a7e44_row8_col5, #T_a7e44_row8_col6, #T_a7e44_row8_col7, #T_a7e44_row9_col0, #T_a7e44_row9_col1, #T_a7e44_row9_col2, #T_a7e44_row9_col3, #T_a7e44_row9_col4, #T_a7e44_row9_col5, #T_a7e44_row9_col6, #T_a7e44_row9_col7, #T_a7e44_row10_col0, #T_a7e44_row10_col1, #T_a7e44_row10_col2, #T_a7e44_row10_col3, #T_a7e44_row10_col4, #T_a7e44_row10_col5, #T_a7e44_row10_col6, #T_a7e44_row10_col7, #T_a7e44_row11_col0, #T_a7e44_row11_col1, #T_a7e44_row11_col2, #T_a7e44_row11_col3, #T_a7e44_row11_col4, #T_a7e44_row11_col5, #T_a7e44_row11_col6, #T_a7e44_row11_col7 {
#   font-size: 16pt;
# }
# </style>
# <table id="T_a7e44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7e44_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a7e44_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a7e44_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a7e44_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a7e44_level0_col4" class="col_heading level0 col4" >1%</th>
#       <th id="T_a7e44_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a7e44_level0_col6" class="col_heading level0 col6" >99%</th>
#       <th id="T_a7e44_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7e44_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_a7e44_row0_col0" class="data row0 col0" >70000.00</td>
#       <td id="T_a7e44_row0_col1" class="data row0 col1" >53.30</td>
#       <td id="T_a7e44_row0_col2" class="data row0 col2" >6.76</td>
#       <td id="T_a7e44_row0_col3" class="data row0 col3" >29.56</td>
#       <td id="T_a7e44_row0_col4" class="data row0 col4" >39.61</td>
#       <td id="T_a7e44_row0_col5" class="data row0 col5" >53.95</td>
#       <td id="T_a7e44_row0_col6" class="data row0 col6" >64.31</td>
#       <td id="T_a7e44_row0_col7" class="data row0 col7" >64.92</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_a7e44_row1_col0" class="data row1 col0" >70000.00</td>
#       <td id="T_a7e44_row1_col1" class="data row1 col1" >1.35</td>
#       <td id="T_a7e44_row1_col2" class="data row1 col2" >0.48</td>
#       <td id="T_a7e44_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_a7e44_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_a7e44_row1_col5" class="data row1 col5" >1.00</td>
#       <td id="T_a7e44_row1_col6" class="data row1 col6" >2.00</td>
#       <td id="T_a7e44_row1_col7" class="data row1 col7" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row2" class="row_heading level0 row2" >height</th>
#       <td id="T_a7e44_row2_col0" class="data row2 col0" >70000.00</td>
#       <td id="T_a7e44_row2_col1" class="data row2 col1" >164.36</td>
#       <td id="T_a7e44_row2_col2" class="data row2 col2" >8.21</td>
#       <td id="T_a7e44_row2_col3" class="data row2 col3" >55.00</td>
#       <td id="T_a7e44_row2_col4" class="data row2 col4" >147.00</td>
#       <td id="T_a7e44_row2_col5" class="data row2 col5" >165.00</td>
#       <td id="T_a7e44_row2_col6" class="data row2 col6" >184.00</td>
#       <td id="T_a7e44_row2_col7" class="data row2 col7" >250.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row3" class="row_heading level0 row3" >weight</th>
#       <td id="T_a7e44_row3_col0" class="data row3 col0" >70000.00</td>
#       <td id="T_a7e44_row3_col1" class="data row3 col1" >74.21</td>
#       <td id="T_a7e44_row3_col2" class="data row3 col2" >14.40</td>
#       <td id="T_a7e44_row3_col3" class="data row3 col3" >10.00</td>
#       <td id="T_a7e44_row3_col4" class="data row3 col4" >48.00</td>
#       <td id="T_a7e44_row3_col5" class="data row3 col5" >72.00</td>
#       <td id="T_a7e44_row3_col6" class="data row3 col6" >117.00</td>
#       <td id="T_a7e44_row3_col7" class="data row3 col7" >200.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row4" class="row_heading level0 row4" >ap_hi</th>
#       <td id="T_a7e44_row4_col0" class="data row4 col0" >70000.00</td>
#       <td id="T_a7e44_row4_col1" class="data row4 col1" >128.82</td>
#       <td id="T_a7e44_row4_col2" class="data row4 col2" >154.01</td>
#       <td id="T_a7e44_row4_col3" class="data row4 col3" >-150.00</td>
#       <td id="T_a7e44_row4_col4" class="data row4 col4" >90.00</td>
#       <td id="T_a7e44_row4_col5" class="data row4 col5" >120.00</td>
#       <td id="T_a7e44_row4_col6" class="data row4 col6" >180.00</td>
#       <td id="T_a7e44_row4_col7" class="data row4 col7" >16020.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row5" class="row_heading level0 row5" >ap_lo</th>
#       <td id="T_a7e44_row5_col0" class="data row5 col0" >70000.00</td>
#       <td id="T_a7e44_row5_col1" class="data row5 col1" >96.63</td>
#       <td id="T_a7e44_row5_col2" class="data row5 col2" >188.47</td>
#       <td id="T_a7e44_row5_col3" class="data row5 col3" >-70.00</td>
#       <td id="T_a7e44_row5_col4" class="data row5 col4" >60.00</td>
#       <td id="T_a7e44_row5_col5" class="data row5 col5" >80.00</td>
#       <td id="T_a7e44_row5_col6" class="data row5 col6" >1000.00</td>
#       <td id="T_a7e44_row5_col7" class="data row5 col7" >11000.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row6" class="row_heading level0 row6" >cholesterol</th>
#       <td id="T_a7e44_row6_col0" class="data row6 col0" >70000.00</td>
#       <td id="T_a7e44_row6_col1" class="data row6 col1" >1.37</td>
#       <td id="T_a7e44_row6_col2" class="data row6 col2" >0.68</td>
#       <td id="T_a7e44_row6_col3" class="data row6 col3" >1.00</td>
#       <td id="T_a7e44_row6_col4" class="data row6 col4" >1.00</td>
#       <td id="T_a7e44_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_a7e44_row6_col6" class="data row6 col6" >3.00</td>
#       <td id="T_a7e44_row6_col7" class="data row6 col7" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row7" class="row_heading level0 row7" >gluc</th>
#       <td id="T_a7e44_row7_col0" class="data row7 col0" >70000.00</td>
#       <td id="T_a7e44_row7_col1" class="data row7 col1" >1.23</td>
#       <td id="T_a7e44_row7_col2" class="data row7 col2" >0.57</td>
#       <td id="T_a7e44_row7_col3" class="data row7 col3" >1.00</td>
#       <td id="T_a7e44_row7_col4" class="data row7 col4" >1.00</td>
#       <td id="T_a7e44_row7_col5" class="data row7 col5" >1.00</td>
#       <td id="T_a7e44_row7_col6" class="data row7 col6" >3.00</td>
#       <td id="T_a7e44_row7_col7" class="data row7 col7" >3.00</td>
#     </tr>
#     <tr>
#       <th id="T_a7e44_level0_row8" class="row_heading level0 row8"

# %%
incorrect_l = cvd_df[(cvd_df['ap_hi'] > 370) | (cvd_df['ap_hi'] <= 40) |\
                     (cvd_df['ap_lo'] > 370) | (cvd_df['ap_lo'] <= 40)].index

print(len(incorrect_l) /  cvd_df.shape[0])
# Out:
# 0.017728571428571427

# %%
cvd_df.drop(incorrect_l, inplace=True)

# %%
cvd_df = cvd_df[cvd_df['ap_hi'] >= cvd_df['ap_lo']].reset_index(drop=True)

# %%
# Target
y = cvd_df['cardio']

# Features
X = cvd_df.drop(['cardio'], axis=1).copy()

# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=9)

# %% [markdown]
# ### Learning about Interpretation Method Types & Scopes

# %%
# Placing Model
log_model = sm.Logit(y_train, sm.add_constant(X_train))

# Fitting Model
log_result = log_model.fit()

print(log_result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.562145
#          Iterations 6
#                          Results: Logit
# =================================================================
# Model:              Logit            Method:           MLE
# Dependent Variable: cardio           Pseudo R-squared: 0.189
# Date:               2025-06-08 14:47 AIC:              65636.3972
# No. Observations:   58359            BIC:              65744.0896
# Df Model:           11               Log-Likelihood:   -32806.
# Df Residuals:       58347            LL-Null:          -40448.
# Converged:          1.0000           LLR p-value:      0.0000
# No. Iterations:     6.0000           Scale:            1.0000
# -----------------------------------------------------------------
#                Coef.   Std.Err.    z     P>|z|   [0.025   0.975]
# -----------------------------------------------------------------
# const         -11.1677   0.2507 -44.5530 0.0000 -11.6590 -10.6764
# age             0.0504   0.0015  34.3350 0.0000   0.0475   0.0532
# gender         -0.0055   0.0238  -0.2329 0.8158  -0.0521   0.0410
# height         -0.0034   0.0014  -2.4417 0.0146  -0.0061  -0.0007
# weight          0.0107   0.0007  14.4555 0.0000   0.0093   0.0122
# ap_hi           0.0556   0.0010  55.3412 0.0000   0.0536   0.0575
# ap_lo           0.0114   0.0016   7.1754 0.0000   0.0083   0.0145
# cholesterol     0.4980   0.0169  29.4792 0.0000   0.4649   0.5311
# gluc           -0.1195   0.0192  -6.2198 0.0000  -0.1572  -0.0818
# smoke          -0.1442   0.0376  -3.8302 0.0001  -0.2180  -0.0704
# alco           -0.1920   0.0459  -4.1829 0.0000  -0.2819  -0.1020
# active         -0.2458   0.0238 -10.3248 0.0000  -0.2925  -0.1992
# =================================================================

# %%
np.exp(log_result.params).sort_values(ascending=False)
# Out:
# cholesterol    1.645409
# ap_hi          1.057123
# age            1.051662
# ap_lo          1.011482
# weight         1.010800
# height         0.996614
# gender         0.994480
# gluc           0.887356
# smoke          0.865710
# alco           0.825331
# active         0.782065
# const          0.000014
# dtype: float64

# %%
np.std(X_train, 0)
# Out:
# age             6.753314
# gender          0.476652
# height          8.186996
# weight         14.331368
# ap_hi          16.682047
# ap_lo           9.434014
# cholesterol     0.678979
# gluc            0.570598
# smoke           0.283529
# alco            0.224476
# active          0.396201
# dtype: float64

# %%
coefs = log_result.params.drop(labels=['const','gender'])

stdv = np.std(X_train, 0).drop(labels='gender')

abs(coefs * stdv).sort_values(ascending=False)
# Out:
# ap_hi          0.926707
# age            0.340174
# cholesterol    0.338124
# weight         0.153945
# ap_lo          0.107705
# active         0.097393
# gluc           0.068192
# alco           0.043093
# smoke          0.040886
# height         0.027770
# dtype: float64

# %% [markdown]
# ### Interpreting Individual Predictions with Logistic Regression

# %%
# Predictions
y_pred = log_result.predict(sm.add_constant(X_test)).to_numpy()

print(y_pred)
# Out:
# [0.6182222  0.33604015 0.21126989 ... 0.30789012 0.26143349 0.31372653]

# %%
# On Patient 2872
print(y_pred[2872])
# Out:
# 0.37922540838638763

# %%
print(X_test.iloc[2872])
# Out:
# age             51.620852
# gender           2.000000
# height         165.000000
# weight          64.000000
# ap_hi          120.000000
# ap_lo           80.000000
# cholesterol      1.000000
# gluc             1.000000
# smoke            0.000000
# alco             0.000000
# active           0.000000
# Name: 19040, dtype: float64

# %%
# Filler Values
filler_feature_values = {"age": 30, "gender": 1, "height": 165, "weight": 57, "ap_hi": 110, 
                         "ap_lo": 70, "cholesterol": 1, "gluc": 1, "smoke": 0, "alco":0, "active":1
                    }

# %%
X_highlight = np.reshape(\
       np.concatenate(([1], X_test.iloc[2872].to_numpy())), (1, 12))

print(X_highlight)
# Out:
# [[  1.          51.62085204   2.         165.          64.
#   120.          80.           1.           1.           0.
#     0.           0.        ]]

# %%
plt.rcParams.update({'font.size': 14, 'figure.dpi':300})

fig, axarr = plt.subplots(2, 2, figsize=(12,8), sharex=True, sharey=False)
mldatasets.create_decision_plot(X_test, y_test, log_result, ["ap_hi", "age"], None, 
                     X_highlight, filler_feature_values, ax=axarr.flat[0])
mldatasets.create_decision_plot(X_test, y_test, log_result, ["ap_hi", "cholesterol"], None, 
                     X_highlight, filler_feature_values, ax=axarr.flat[1])
mldatasets.create_decision_plot(X_test, y_test, log_result, ["ap_hi", "ap_lo"], None, 
                     X_highlight, filler_feature_values, ax=axarr.flat[2])
mldatasets.create_decision_plot(X_test, y_test, log_result, ["ap_hi", "weight"], None, 
                     X_highlight, filler_feature_values, ax=axarr.flat[3])
plt.subplots_adjust(top = 1, bottom=0, hspace=0.2, wspace=0.2)

plt.show()

# %% [markdown]
# ### Appreciate what Hinders Machine Learning Interpretability

# %%
fig, ax = plt.subplots(1,1, figsize=(12,8))

mldatasets.create_decision_plot(X_test, y_test, log_result, [3,4], ['height [cm]', 'weight [kg]'], 
                     X_highlight, filler_feature_values, ax=ax)
plt.show()

# %% [markdown]
# ### Non-Linearity

# %%
X2 = cvd_df.drop(['cardio'], axis=1).copy()

X2["bmi"] = X2["weight"] / (X2["height"]/100)**2

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(15,4))

sns.regplot(x="weight", y="bmi", data=X2, ax=ax1, color='darkorange')
sns.regplot(x="height", y="bmi", data=X2, ax=ax2, color='royalblue')
sns.regplot(x="height", y="weight", data=X2, ax=ax3, color='forestgreen')
plt.subplots_adjust(top = 1, bottom=0, hspace=0.2, wspace=0.3)
plt.show()

# %%
X2 = X2.drop(['weight','height'], axis=1)

X2_train, X2_test, _, _ = train_test_split(X2, y, test_size=0.15, random_state=9)

log_model2 = sm.Logit(y_train, sm.add_constant(X2_train))
log_result2 = log_model2.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.562766
#          Iterations 6

# %%
sns.reset_orig()

# %%
filler_feature_values2 = {"age": 60, "gender": 1, "ap_hi": 110, "ap_lo": 70, "cholesterol": 1, "gluc": 1,\
                          "smoke": 0, "alco":0, "active":1, "bmi":20}
X2_highlight = np.reshape(np.concatenate(([1],X2_test.iloc[2872].to_numpy())), (1, 11))

fig, ax = plt.subplots(1,1, figsize=(12,8))
mldatasets.create_decision_plot(X2_test, y_test, log_result2, ["ap_hi", "bmi"], None,
                     X2_highlight, filler_feature_values2, ax=ax)
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ba9b5989-2562-4e33-a9ca-8ebf28a1b6ee' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
