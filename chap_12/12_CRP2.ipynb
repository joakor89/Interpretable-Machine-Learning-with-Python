# %% [markdown]
# # Criminal Recidivism Prediction (Part 2)

# %% [markdown]
# ### Preparations

# %%
# !python chapter_setup.py

# %%
# Install the missing library
# !apt-get update && apt-get install -y libgl1-mesa-glx

# %% [markdown]
# ### Loading Libraries

# %%
import scipy

# %%
# Numerical Computing
import math
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
# import xai
import seaborn as sns
import matplotlib.pyplot as plt

# Model Agnostic
import shap

# OS
import os
import copy

# Dataset Source
import machine_learning_datasets as mldatasets

# Scikit-Learn
from sklearn import preprocessing, model_selection, metrics,\
                    linear_model, svm, neural_network, ensemble

# Extreme Gradient Booster
import xgboost as xgb

# LightGBM
import lightgbm as lgb

# Categorical Booster
import catboost as cb

# Tensor Flow
import tensorflow as tf
import tensorflow_lattice as tfl

# Bayes Optimization
from bayes_opt import BayesianOptimization
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 24
#      21 import machine_learning_datasets as mldatasets
#      23 # Scikit-Learn
# ---> 24 from sklearn import preprocessing, model_selection, metrics,\
#      25                     linear_model, svm, neural_network, ensemble
#      27 # Extreme Gradient Booster
#      28 import xgboost as xgb
#
# File ~/venv/lib/python3.10/site-packages/sklearn/neural_network/__init__.py:6
#       1 """Models based on neural networks."""
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
# ----> 6 from ._multilayer_perceptron import MLPClassifier, MLPRegressor
#       7 from ._rbm import BernoulliRBM
#       9 __all__ = ["BernoulliRBM", "MLPClassifier", "MLPRegressor"]
#
# File ~/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:14
#      11 import numpy as np
#      12 import scipy.optimize
# ---> 14 from ..base import (
#      15     BaseEstimator,
#      16     ClassifierMixin,
#      17     RegressorMixin,
#      18     _fit_context,
#      19     is_classifier,
#      20 )
#      21 from ..exceptions import ConvergenceWarning
#      22 from ..metrics import accuracy_score, r2_score
#
# ImportError: cannot import name '_fit_context' from 'sklearn.base' (/root/venv/lib/python3.10/site-packages/sklearn/base.py)

# %%
from scikeras.wrappers import KerasClassifier

# %%
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(tf.__version__)
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ### Understanding & Preparing Data

# %%
recidivism_df = mldatasets.load("recidivism-risk-balanced")

# %%
recidivism_df.info()

# %% [markdown]
# - Verifying the Sampling Balance

# %%
categorical_cols_l = ['sex', 'race', 'c_charge_degree',\
                      'is_recid', 'compas_score']
xai.imbalance_plot(recidivism_df, 'race', 'is_recid',\
                   categorical_cols=categorical_cols_l)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=36aa147d-05e0-421f-a3e0-2388eb0958c2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
